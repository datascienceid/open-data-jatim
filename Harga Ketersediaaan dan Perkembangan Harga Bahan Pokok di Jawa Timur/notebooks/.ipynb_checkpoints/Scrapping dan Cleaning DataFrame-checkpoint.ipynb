# %%
import pandas as pd
import requests

# %%
r = requests.post('http://siskaperbapo.com/harga/tabel.nodesign/', data={'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
                                                                         'tanggal': '2017-01-01', 
                                                                         'kabkota': ''})

# %%
df = pd.read_html(r.text, header=0)[0]

# %%
harga = df[['NAMA BAHAN POKOK', 'SATUAN', 'HARGA SEKARANG']]

# %%
harga
# Out:
#                          NAMA BAHAN POKOK      SATUAN HARGA SEKARANG
# 0                                   BERAS         NaN            NaN
# 1                              - Bengawan          kg         10.407
# 2                                - Mentik          kg         10.299
# 3                                 - IR 64          kg          8.863
# 4                              GULA PASIR         NaN            NaN
# 5                - Gula Pasir Dalam Negri          kg         12.637
# 6                           MINYAK GORENG         NaN            NaN
# 7   - Bimoli Botol / Kemasan (Sps) 620 ml      620 ml         11.677
# 8    - Bimoli botol/Kemasan (sps) 2 liter     2 Liter         25.445
# 9             - Tanpa Merk / Minyak Curah          kg         11.623
# 10                                 DAGING         NaN            NaN
# 11                    - Daging Sapi Murni          kg        105.444
# 12                  - Daging Ayam Broiler          kg         29.565
# ...

# %%
nama_bahan = harga['NAMA BAHAN POKOK']

# %%
nama_bahan.tolist()
# Out:
# ['BERAS',
#  '- Bengawan',
#  '- Mentik',
#  '- IR 64',
#  'GULA PASIR',
#  '- Gula Pasir Dalam Negri',
#  'MINYAK GORENG',
#  '- Bimoli Botol / Kemasan (Sps) 620 ml',
#  '- Bimoli botol/Kemasan (sps) 2 liter',
#  '- Tanpa Merk / Minyak Curah',
#  'DAGING',
#  '- Daging Sapi Murni',
#  '- Daging Ayam Broiler',
#  '- Daging Ayam Kampung',
#  'TELUR AYAM',
#  '- Telur Ayam Ras / Petelur',
#  '- Telur Ayam Kampung',
#  'SUSU',
#  'Kental Manis',
#  '- Susu Kental Manis Merk Bendera',
#  '- Susu Kental Manis Merk Indomilk',
#  'Susu Bubuk',
#  '- Susu Bubuk Merk Bendera (Instant)',
#  '- Susu Bubuk Merk Indomilk (Instant)',
#  '- JAGUNG PIPILAN KERING',
#  '- GARAM BERYODIUM',
#  '- Bata',
#  '- Halus',
#  'TEPUNG TERIGU',
#  '- Segitiga Biru (Kw Medium)',
#  'KACANG KEDELAI',
#  '- Eks Impor',
#  '- Lokal',
#  'MIE INSTANT',
#  '- Indomie Rasa Kari Ayam',
#  'CABE',
#  '- Keriting',
#  '- Biasa',
#  '- Cabe Rawit',
#  '- BAWANG MERAH',
#  '- BAWANG PUTIH',
#  '- IKAN ASIN TERI',
# ...

# %%
# Manual Edit
nama_bahan_pokok = ['BERAS',
 'Beras Bengawan',
 'Beras Mentik',
 'Beras IR 64',
 'GULA PASIR',
 'Gula Pasir Dalam Negri',
 'MINYAK GORENG',
 'Bimoli Botol / Kemasan (Sps)',
 'Bimoli botol/Kemasan (sps)',
 'Tanpa Merk / Minyak Curah',
 'DAGING',
 'Daging Sapi Murni',
 'Daging Ayam Broiler',
 'Daging Ayam Kampung',
 'TELUR AYAM',
 'Telur Ayam Ras / Petelur',
 'Telur Ayam Kampung',
 'SUSU',
 'Susu Kental Manis',
 'Susu Kental Manis Merk Bendera',
 'Susu Kental Manis Merk Indomilk',
 'Susu Bubuk',
 'Susu Bubuk Merk Bendera (Instant)',
 'Susu Bubuk Merk Indomilk (Instant)',
 'JAGUNG PIPILAN KERING',
 'GARAM BERYODIUM',
 'Garam Bata',
 'Garam Halus',
 'TEPUNG TERIGU',
 'Tepung Segitiga Biru (Kw Medium)',
 'KACANG KEDELAI',
 'Kacang Kedelai Eks Impor',
 'Kacang Kedelai Lokal',
 'MIE INSTANT',
 'Indomie Rasa Kari Ayam',
 'CABE',
 'Cabe Keriting',
 'Cabe Biasa',
 'Cabe Rawit',
 'BAWANG MERAH',
 'BAWANG PUTIH',
 'IKAN ASIN TERI',
 'KACANG HIJAU',
 'KACANG TANAH',
 'KETELA POHON',
 'SAYUR MAYUR',
 'KOL/KUBIS',
 'KENTANG',
 'TOMAT',
 'WORTEL',
 'BUNCIS',
 'SEMEN',
 'Semen Gresik',
 'Semen Tiga Roda',
 'Semen Holcim',
 'Semen Padang',
 'Semen Tonasa',
 'Semen Bosowa',
 'IKAN SEGAR',
 'Ikan Bandeng',
 'Ikan Kembung',
 'Ikan Tuna',
 'ikan Tongkol',
 'ikan cakalang',
 'KAYU BALOK MERANTI (4 X 10)',
 'PAPAN MERANTI (4m X 3cm X 20mm)',
 'TRIPLEK (6MM)',
 'BESI BETON (SNI MURNI)',
 'Besi Beton 6 mm (12/9m)',
 'Besi Beton 8 mm (12/9m)',
 'Besi Beton 10 mm (12/9m)',
 'Besi Beton 12 mm (12/9m)',
 'PAKU',
 'Paku Ukuran 10Cm',
 'Paku Ukuran 2 Cm',
 'Paku Ukuran 3Cm',
 'Paku Ukuran 4Cm',
 'Paku Ukuran 5Cm',
 'Paku Ukuran 7Cm',
 'GAS ELPIGI 3 Kg',
 'PUPUK',
 'Pupuk KCL Non Subsidi',
 'Pupuk NPK Non Subsidi',
 'Pupuk SP 35 Non Subsidi',
 'Pupuk Urea Non Subsidi',
 'Pupuk ZA Non Subsidi']

# %%
nama_bahan = pd.Series(nama_bahan_pokok)

# %%
harga['NAMA BAHAN POKOK'] = nama_bahan
# Out:
# /home/rubiagatra/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
harga = harga[~harga['SATUAN'].isnull()]

# %%
harga
# Out:
#                       NAMA BAHAN POKOK      SATUAN HARGA SEKARANG
# 1                       Beras Bengawan          kg         10.407
# 2                         Beras Mentik          kg         10.299
# 3                          Beras IR 64          kg          8.863
# 5               Gula Pasir Dalam Negri          kg         12.637
# 7         Bimoli Botol / Kemasan (Sps)      620 ml         11.677
# 8           Bimoli botol/Kemasan (sps)     2 Liter         25.445
# 9            Tanpa Merk / Minyak Curah          kg         11.623
# 11                   Daging Sapi Murni          kg        105.444
# 12                 Daging Ayam Broiler          kg         29.565
# 13                 Daging Ayam Kampung          kg         55.500
# 15            Telur Ayam Ras / Petelur          kg         20.003
# 16                  Telur Ayam Kampung          kg         36.356
# 19      Susu Kental Manis Merk Bendera   397 gr/kl          9.864
# ...

# %%
harga['SATUAN'] =  harga['SATUAN'].str.title()
harga['NAMA BAHAN POKOK'] =  harga['NAMA BAHAN POKOK'].str.title()
harga['HARGA SEKARANG'] = harga['HARGA SEKARANG'].str.replace('.', '').astype('int32')
# Out:
# /home/rubiagatra/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /home/rubiagatra/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /home/rubiagatra/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
harga['NAMA BAHAN POKOK'] = harga['NAMA BAHAN POKOK'] + ' ' + '(' + harga['SATUAN'] + ')'
# Out:
# /home/rubiagatra/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
harga.index = range(len(harga))
harga = harga[['NAMA BAHAN POKOK', 'HARGA SEKARANG']]

# %%
harga_transpose = harga.transpose().copy()
harga_transpose.columns = harga_transpose.iloc[0, :]
harga_series = harga_transpose.iloc[1,:].copy()
harga_series.name = '2017-01-01'

# %%
harga_series
# Out:
# NAMA BAHAN POKOK
# Beras Bengawan (Kg)                                 10407
# Beras Mentik (Kg)                                   10299
# Beras Ir 64 (Kg)                                     8863
# Gula Pasir Dalam Negri (Kg)                         12637
# Bimoli Botol / Kemasan (Sps) (620 Ml)               11677
# Bimoli Botol/Kemasan (Sps) (2 Liter)                25445
# Tanpa Merk / Minyak Curah (Kg)                      11623
# Daging Sapi Murni (Kg)                             105444
# Daging Ayam Broiler (Kg)                            29565
# Daging Ayam Kampung (Kg)                            55500
# Telur Ayam Ras / Petelur (Kg)                       20003
# Telur Ayam Kampung (Kg)                             36356
# Susu Kental Manis Merk Bendera (397 Gr/Kl)           9864
# Susu Kental Manis Merk Indomilk (390 Gr/Kl)          9705
# Susu Bubuk Merk Bendera (Instant) (400 Gr/Dos)      37128
# Susu Bubuk Merk Indomilk (Instant) (400 Gr/Dos)     35343
# ...

# %%
harga_series.to_csv('../data/Harga Jawa Timur 2017-01-01.csv')
